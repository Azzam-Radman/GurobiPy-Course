# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/input_data.csv')
df
# Out:
#    Supplier/Demand   0   1   2   3
# 0                0  15  17  14  18
# 1                1  18  12  13  19
# 2                2  13  15  16  13

# %%
df = pd.read_excel('/content/input_data.xlsx')
df
# Out:
#    Supplier/Demand   0   1   2   3
# 0                0  15  17  14  18
# 1                1  18  12  13  19
# 2                2  13  15  16  13

# %%
df.iloc[2]
# Out:
# Supplier/Demand     2
# 0                  13
# 1                  15
# 2                  16
# 3                  13
# Name: 2, dtype: int64

# %%
df.iloc[:, 4]
# Out:
# 0    18
# 1    19
# 2    13
# Name: 3, dtype: int64

# %%
df.iloc[:, 1:]
# Out:
#     0   1   2   3
# 0  15  17  14  18
# 1  18  12  13  19
# 2  13  15  16  13

# %%
df.iloc[:, 1:].values
# Out:
# array([[15, 17, 14, 18],
#        [18, 12, 13, 19],
#        [13, 15, 16, 13]])
